# %% [markdown]
# Testing how Google Colab works.. trying out some Pyton code

# %%
print("Hello world!")
# Out:
# Hello world!

# %% [markdown]
# Let's get some user input

# %%
print("Let's add two numbers!")
a = int(input("Enter a number: "))
b = int(input("Enter another number to add to %s: " % str(a)))
sum = a + b
print("Result is %s" % str(sum))
# Out:
# Let's add two numbers!
# Result is 707
