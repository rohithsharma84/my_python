# %% [markdown]
# # Building an MCP Server for Market Research
#
# **Objective**: To build an MCP server as a foundation for automated market research by connecting it to Tavily, defining tools and prompts for competitor and product analysis, and running it in Cursor to generate structured briefs and insights for product decisions
#
# **Tools required**: Cursor AI

# %%
% pip install fastmcp tavily-python
